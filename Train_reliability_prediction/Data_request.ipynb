# %% [markdown]
# <a href="https://colab.research.google.com/github/Arajit-Pati/Projects/blob/main/Train_reliability_prediction/Data_request.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Scraping railway schedules and average delay data from relevant open source sites**
# Links:
# - For schedule -> https://www.cleartrip.com/trains/stations/SC/
# - For delay -> https://www.railyatri.in//insights/average-train-delay-at-station/sc
#
# **Disclaimer - The data does not breach any individual information of importance.**

# %% [markdown]
# ## Install Required Packages

# %%
# !pip install cloudscraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Importing libraries

# %%
from bs4 import BeautifulSoup
import requests
import cloudscraper
import pandas as pd

# %% [markdown]
# ## Pull requests
# Avoid cloudfare protection against bots

# %%
url = 'https://www.cleartrip.com/trains/stations/SC/'

scraper = cloudscraper.create_scraper() # for scraping from cloudfare protected sites
page = scraper.get(url)
# print(page)

soup = BeautifulSoup(page.text, "html")

# %% [markdown]
# Pulls out html text

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="noodp,noydir" name="robots"/>
# <link href="https://www.cleartrip.com/trains/stations/SC/" rel="canonical"/>
# <link href="https://www.cleartrip.com/trains/stations/SC/" hreflang="en-IN" rel="alternate"/>
# <script>
# 		  var mixpanelid ='1f2a332877a16b23065f7ad8a4a2a085';
# 		</script>
# <link href="https://www.cleartrip.com/trains/stations/amp/SC" rel="amphtml"/>
# <meta content="Check trains from Secunderabad Junction railway station – find details about fares, available dates, reservation, seat availability, train schedule. Find trains originating and passing through Secunderabad Junction at Cleartrip.com" name="description"/>
# ...

# %%
table = soup.find_all('table', class_ = 'results')[0]

# %%
print(table)
# Out:
# <table class="results">
# <thead>
# <tr>
# <th abbr="Train name &amp; number" scope="col">Train name (no.) passing via <br/> Secunderabad Junction</th>
# <th abbr="Arrival time" scope="col" width="10%">Arrives</th>
# <th abbr="Departure time" scope="col" width="9%">Departs</th>
# <th abbr="Wait time" scope="col">Stop time</th>
# <th abbr="Monday" scope="col">M</th>
# <th abbr="Tuesday" scope="col">T</th>
# <th abbr="Wednesday" scope="col">W</th>
# <th abbr="Thursday" scope="col">T</th>
# <th abbr="Friday" scope="col">F</th>
# <th abbr="Saturday" scope="col">S</th>
# <th abbr="Sunday" scope="col">S</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="trainName"><a href="/trains/12733">Narayanadri Express</a> (12733)</td>
# <td>06:25</td>
# <td><strong>Ends</strong></td>
# <td></td>
# <td>Y</td><td>Y</td><td>Y</td><td>Y</td><td>Y</td><td>Y</td><td>Y</td>
# </tr>
# <tr>
# <td class="trainName"><a href="/trains/12747">Palnadu Express</a> (12747)</td>
# <td>10:35</td>
# <td>10:45</td>
# ...

# %%
titles = table.find_all('th')

# %%
print(titles)
# Out:
# [<th abbr="Train name &amp; number" scope="col">Train name (no.) passing via <br/> Secunderabad Junction</th>, <th abbr="Arrival time" scope="col" width="10%">Arrives</th>, <th abbr="Departure time" scope="col" width="9%">Departs</th>, <th abbr="Wait time" scope="col">Stop time</th>, <th abbr="Monday" scope="col">M</th>, <th abbr="Tuesday" scope="col">T</th>, <th abbr="Wednesday" scope="col">W</th>, <th abbr="Thursday" scope="col">T</th>, <th abbr="Friday" scope="col">F</th>, <th abbr="Saturday" scope="col">S</th>, <th abbr="Sunday" scope="col">S</th>]

# %%
rail_titles = [title.text for title in titles]
print(rail_titles)
# Out:
# ['Train name (no.) passing via  Secunderabad Junction', 'Arrives', 'Departs', 'Stop time', 'M', 'T', 'W', 'T', 'F', 'S', 'S']

# %% [markdown]
# ### Convert into dataframes

# %%
df = pd.DataFrame(columns = rail_titles)

df
# Out:
# Empty DataFrame
# Columns: [Train name (no.) passing via  Secunderabad Junction, Arrives, Departs, Stop time, M, T, W, T, F, S, S]
# Index: []

# %%
columns_data = table.find_all('tr')
columns_data
# Out:
# [<tr>
#  <th abbr="Train name &amp; number" scope="col">Train name (no.) passing via <br/> Secunderabad Junction</th>
#  <th abbr="Arrival time" scope="col" width="10%">Arrives</th>
#  <th abbr="Departure time" scope="col" width="9%">Departs</th>
#  <th abbr="Wait time" scope="col">Stop time</th>
#  <th abbr="Monday" scope="col">M</th>
#  <th abbr="Tuesday" scope="col">T</th>
#  <th abbr="Wednesday" scope="col">W</th>
#  <th abbr="Thursday" scope="col">T</th>
#  <th abbr="Friday" scope="col">F</th>
#  <th abbr="Saturday" scope="col">S</th>
#  <th abbr="Sunday" scope="col">S</th>
#  </tr>,
#  <tr>
#  <td class="trainName"><a href="/trains/12733">Narayanadri Express</a> (12733)</td>
#  <td>06:25</td>
#  <td><strong>Ends</strong></td>
#  <td></td>
#  <td>Y</td><td>Y</td><td>Y</td><td>Y</td><td>Y</td><td>Y</td><td>Y</td>
#  </tr>,
#  <tr>
#  <td class="trainName"><a href="/trains/12747">Palnadu Express</a> (12747)</td>
#  <td>10:35</td>
#  <td>10:45</td>
#  <td>10 min</td>
# ...

# %% [markdown]
# Adding subsequent rows

# %%
for row in columns_data[1:]:
  row_data = row.find_all('td')
  entries = [entry.text for entry in row_data]
  length = len(df)
  df.loc[length] = entries

df.head()
# Out:
#   Train name (no.) passing via  Secunderabad Junction Arrives Departs  \
# 0                        Narayanadri Express (12733)    06:25    Ends
# 1                            Palnadu Express (12747)    10:35   10:45
# 2                          Charminar Express (12759)    07:15   07:20
# 3                        Link Secbad Express (57140)    04:45    Ends
# 4                           Nzb Vskp Special (08566)    21:10   21:30
#
#   Stop time  M  T  W  T  F  S  S
# 0            Y  Y  Y  Y  Y  Y  Y
# 1    10 min  Y  Y  Y  Y  Y  Y  Y
# 2     5 min  Y  Y  Y  Y  Y  Y  Y
# 3            Y  Y  Y  Y  Y  Y  Y
# 4    20 min  N  N  Y  N  N  N  N

# %%
print(df.columns)
# Out:
# Index(['Train name (no.) passing via  Secunderabad Junction', 'Arrives',
#        'Departs', 'Stop time', 'M', 'T', 'W', 'T', 'F', 'S', 'S'],
#       dtype='object')

# %%
train_no = [train.split("(") for train in df["Train name (no.) passing via  Secunderabad Junction"]]

# %%
# train_no
numbers = [number[1].split(')') for number in train_no]
numbers = [number[0] for number in numbers]

train_num = pd.DataFrame(numbers, columns = ["Train number"])

final_df = pd.concat([train_num, df], axis = 1)
final_df.head()
# Out:
#   Train number Train name (no.) passing via  Secunderabad Junction Arrives  \
# 0        12733                        Narayanadri Express (12733)    06:25
# 1        12747                            Palnadu Express (12747)    10:35
# 2        12759                          Charminar Express (12759)    07:15
# 3        57140                        Link Secbad Express (57140)    04:45
# 4        08566                           Nzb Vskp Special (08566)    21:10
#
#   Departs Stop time  M  T  W  T  F  S  S
# 0    Ends            Y  Y  Y  Y  Y  Y  Y
# 1   10:45    10 min  Y  Y  Y  Y  Y  Y  Y
# 2   07:20     5 min  Y  Y  Y  Y  Y  Y  Y
# 3    Ends            Y  Y  Y  Y  Y  Y  Y
# 4   21:30    20 min  N  N  Y  N  N  N  N

# %% [markdown]
# ### Save the file in csv format !!

# %%
final_df.to_csv(r"sample_data/train_schedule_SC.csv")

# %% [markdown]
# # ...........

# %% [markdown]
# # ..........

# %% [markdown]
# ## Scraping average delay in arrival times for certain trains

# %% [markdown]
# _..... Starting of a repetitive block of code to accumulate all data from a sequence of webpages_

# %%
url2 = "https://www.railyatri.in//insights/average-train-delay-at-station/sc"

page2 = requests.get(url2)

soup2 = BeautifulSoup(page2.text, "html")

print(soup2)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta cache-control="no-transform"/>
# <title>Average Train Delay @ Station</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="A first of its kind - Insights is a travel tool powered by intelligent big data mining to give you the most comprehensive view of your train/station or destination. This can also be used as a decision making tool to choose between many options for your journey." name="description"/>
# <meta content="India Travel, Indian Railways, Trains, Travel across India, Things to do in India, how to reach, Train Station, Time Table, Train Schedules, Train Arrivals, Train Delays, Online Tracking, Mobile Tracking, Cheap Travel, yatra, RailYatri, Journey Planner, Trip Planner" name="keywords"/>
# <!--[if lt IE 9] >
#         <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# ...

# %% [markdown]
# - **This snippet ensures that the we can navigate to the next webpage**

# %%
next = soup2.find_all('div', class_ = 'pages')[0]

to = next.find_all('a')[1]

to
# Out:
# <a href="javascript:void(0)" style="" title="No More Data">&gt;</a>

# %%
delay_board = soup2.find_all('script', type = 'text/javascript')[2]

print(delay_board)
# Out:
# <script type="text/javascript">
#
# ...

# %%
stage = delay_board.text

print(stage)
# Out:
#     var chart_data = [{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":0,"day":1,"value":1},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":1,"day":1,"value":29},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":2,"day":1,"value":27},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":3,"day":1,"value":0},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":4,"day":1,"value":24},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":5,"day":1,"value":27},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":6,"day":1,"value":53},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":
# ...

# %%
pecker = stage.split('\n')

train_list = pecker[2]

# %%
list_s_idx = train_list.find('[')

list_e_idx = train_list.find(']')

train_list = train_list[list_s_idx+1:list_e_idx]

print(train_list)
# Out:
# {"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":0,"day":1,"value":1},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":1,"day":1,"value":29},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":2,"day":1,"value":27},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":3,"day":1,"value":0},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":4,"day":1,"value":24},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":5,"day":1,"value":27},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":6,"day":1,"value":53},{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":7,"day":1,"value":17},
# ...

# %%
delay_list = train_list.split('},{')

delay_list[0] = delay_list[0][1:]
delay_list[-1] = delay_list[-1][:-1]

# %%
delay_list = ["{" + train_data + "}" for train_data in delay_list]

delay_list
# Out:
# ['{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":0,"day":1,"value":1}',
#  '{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":1,"day":1,"value":29}',
#  '{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":2,"day":1,"value":27}',
#  '{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":3,"day":1,"value":0}',
#  '{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":4,"day":1,"value":24}',
#  '{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":5,"day":1,"value":27}',
#  '{"number":"22705 (27 mins) ","name":"Humsafar Express","full_number":"22705 - Humsafar Express","hour":6,"day":1,"value":53}',
# ...

# %% [markdown]
# - **This snippet is to be executed only for the first execution of the repetitive block**

# %%
# delay_data = [eval(train_data) for train_data in delay_list]

# len(delay_data)

# %% [markdown]
# - **This snippet is to be executed for the further executions of the repetitive block**

# %%
temp = [eval(train_data) for train_data in delay_list]

delay_data = delay_data + temp

len(delay_data)
# Out:
# 8069

# %% [markdown]
# _... The repetitive block ends here_
#
# ........
#
# Now we will retrieve everything into DataFrame

# %%
avg_delay = []

for dict in delay_data:
  if dict["number"] not in avg_delay:
    avg_delay.append(dict["number"])

tr_no = [number.split(' (')[0] for number in avg_delay]
delay_mins = [int(number.split(' (')[1].strip()[:-6]) for number in avg_delay]

print(delay_mins) #remember this is an int
# Out:
# [63, 30, 5, 5, 22, 79, 7, 2, 3, 60, 7, 1, 0, 42, 7, 3, 83, 0, 23, 9, 0, 5, 83, 6, 4, 7, 15, 6, 43, 10, 22, 99, 16, 69, 63, 11, 14, 4, 22, 23, 4, 4, 55, 14, 6, 2, 4, 7, 39, 7, 107, 35, 26, 38, 5, 60, 60, 10, 14, 8, 12, 2, 2, 54, 8, 3, 74, 17, 0, 4, 23, 38, 7, 37, 21, 0, 24, 6, 56, 6, 36, 1, 12, 235, 15, 265, 3, 0, 30, 45, 28, 4, 3, 0, 10, 0, 16, 3, 68, 4, 7, 20, 0, 40, 3, 36, 59, 0, 48, 4, 70, 3, 2, 1, 38, 0, 0, 11, 10, 46, 347, 68, 6, 83, 0, 0, 4, 25, 5, 80, 15, 0, 120, 23, 60, 5, 49, 15, 34, 28, 1, 3, 3, 0, 59, 12, 20, 15, 0, 1, 6, 0, 0, 4, 90, 20, 1, 53, 27, 180, 28, 1, 45, 0, 19, 4, 6, 26]

# %%
print(len(tr_no), len(delay_mins))
# Out:
# 168 168

# %%
# fetch delay for each of the 49 pointers
pointers = [];
temp = [];
last = delay_data[0]["number"]

for i in range(len(delay_data)):
  temp.append(delay_data[i]["value"])

  if delay_data[i]["number"] != last:
    pointers.append(temp)
    temp = []
    last = delay_data[i]["number"]

if len(temp) > 0:
  pointers.append(temp)

pointers = [tuple(ele) for ele in pointers]

# %%
len(pointers)
# Out:
# 168

# %%
columns = ["ptr "+ str(i) for i in range(75)]

delay_frame = pd.DataFrame(pointers, columns = columns)

# %%
delay_frame_2 = pd.DataFrame(zip(tr_no, delay_mins), columns = ["Train number", "Delay in mins"])

# %%
delay_frame = pd.concat([delay_frame_2, delay_frame], axis = 1)

# %%
delay_frame.head()
# Out:
#   Train number  Delay in mins  ptr 0  ptr 1  ptr 2  ptr 3  ptr 4  ptr 5  \
# 0        11019             63    117     69   69.0   17.0   33.0   35.0
# 1        11020             30     13     16   30.0    2.0   40.0    6.0
# 2        12025              5      4      1    9.0   -5.0   12.0   -1.0
# 3        12026              5      7      0    3.0   13.0   16.0    1.0
# 4        12213             22     30     26   11.0   23.0   48.0   21.0
#
#    ptr 6  ptr 7  ...  ptr 65  ptr 66  ptr 67  ptr 68  ptr 69  ptr 70  ptr 71  \
# 0   21.0   21.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   16.0  -30.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2   21.0    1.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3   37.0   29.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4   74.0   15.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    ptr 72  ptr 73  ptr 74
# 0     NaN     NaN     NaN
# ...

# %% [markdown]
# Save file in csv format

# %%
delay_frame.to_csv(r"sample_data/avg_delay.csv")
